# %%
from scipy import misc
from scipy import ndimage
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Carregando a Imagem a ser tratada

# %%
img = misc.imread("baboon.png")

# %% [markdown]
# ### Dimensões da Imagem Carregada

# %%
print (img.shape)
# Out:
# (512, 512)

# %%
plt.imshow(img, cmap="gray")
plt.show()

# %%
print("largura:",img.shape[1])
print("altura:",img.shape[0])
print("intensidade mínima:",img.min())
print("intensidade máxima:",img.max())
print("intensidade média: %0.2f" % img.mean())
# Out:
# largura: 512
# altura: 512
# intensidade mínima: 0
# intensidade máxima: 230
# intensidade média: 129.15

# %%
histogram_example = plt.hist(img)
plt.xlabel("Níveis de cinza")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# ### Gerando o negativo

# %%
img_neg = 255 - img

# %%
plt.imshow(img_neg, cmap="gray")
plt.show()

# %% [markdown]
# ### Aplicando a transformação sobre a imagem

# %%
img_tr = ((60/255) * img) + 120

# %%
plt.imshow(img_tr, cmap="gray", vmin=0, vmax=255)
plt.show()

# %%
print("largura:",img_tr.shape[1])
print("altura:",img_tr.shape[0])
print("intensidade mínima: %0.f" % img_tr.min())
print("intensidade máxima: %0.f" % img_tr.max())
print("intensidade média: %0.f" % img_tr.mean())
# Out:
# largura: 512
# altura: 512
# intensidade mínima: 120
# intensidade máxima: 174
# intensidade média: 150
